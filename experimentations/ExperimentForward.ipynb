# %% [markdown]
# # Simplest Topo

# %% [markdown]
# The setup here forwards when we add the rules in the table through the network setup.
#
# 1. mainfile: forward.p4
# 2. compiled: forward.json/forward.p4i
# 3. h1 -> h2 -> h1 is shown.

# %%
import os
import subprocess
import time
from mininet.net import Mininet
from mininet.topo import Topo
from mininet.node import Switch
from mininet.cli import CLI
from mininet.log import setLogLevel, info

class P4Switch(Switch):
    def __init__(self, name, json_file, thrift_port=9090, **params):
        Switch.__init__(self, name, **params)
        self.json_file = json_file
        self.thrift_port = thrift_port
        self.interfaces = []  # Store interfaces to bind

    def start(self, controllers):
        # Get interfaces from Mininet (e.g., s1-eth0, s1-eth1)
        intf_args = " ".join(f"--interface {idx}@{intf.name}" for idx, intf in enumerate(self.intfList()) if intf.name != "lo")
        cmd = f"simple_switch --thrift-port {self.thrift_port} --log-console --log-level trace {intf_args} {self.json_file} &"
        info(f"*** Starting P4 switch {self.name}: {cmd}\n")
        os.system(cmd)
        time.sleep(5)  # Wait for switch to bind interfaces

    def stop(self):
        info(f"*** Stopping P4 switch {self.name}\n")
        os.system("pkill simple_switch")

class NetworkTopo(Topo):
    def __init__(self, json_file):
        Topo.__init__(self)
        s1 = self.addSwitch('s1', cls=P4Switch, json_file=json_file, thrift_port=9090)
        h1 = self.addHost('h1', ip='10.0.1.1/24', mac='00:00:00:00:01:01')
        h2 = self.addHost('h2', ip='10.0.1.2/24', mac='00:00:00:00:01:02')
        self.addLink(h1, s1, port1=0, port2=0)
        self.addLink(h2, s1, port1=0, port2=1)

def compile_p4_program():
    print("Compiling P4 program...")
    try:
        subprocess.run(['p4c', '--target', 'bmv2', '--arch', 'v1model', '-o', '.', 'forward.p4'], check=True)
        print("P4 compilation successful")
        time.sleep(5)
    except subprocess.CalledProcessError as e:
        print(f"P4 compilation failed: {e}")
        exit(1)

def setup_network():
    json_file = "forward.json"
    net = Mininet(topo=NetworkTopo(json_file), controller=None)
    try:
        net.start()
        s1 = net.get('s1')
        s1.cmd('simple_switch_CLI --thrift-port 9090 << EOF\n'
               'mc_mgrp_create 1\n'
               'mc_node_create 0 0 1\n'
               'mc_node_associate 1 0\n'
               'EOF')
        s1.cmd('simple_switch_CLI --thrift-port 9090 << EOF\n'
               'table_add ipv4_lpm forward 10.0.1.1/32 => 0\n'
               'table_add ipv4_lpm forward 10.0.1.2/32 => 1\n'
               'EOF')
        h1, h2 = net.get('h1', 'h2')
        h1.cmd('ifconfig h1-eth0 10.0.1.1/24 up')
        h2.cmd('ifconfig h2-eth0 10.0.1.2/24 up')
        h1.cmd('arp -i h1-eth0 -s 10.0.1.2 00:00:00:00:01:02')
        h2.cmd('arp -i h2-eth0 -s 10.0.1.1 00:00:00:00:01:01')
        h1.cmd('ip route add 10.0.1.0/24 dev h1-eth0')
        h2.cmd('ip route add 10.0.1.0/24 dev h2-eth0')
        
        info("*** h1 interface config:\n")
        print(h1.cmd('ifconfig h1-eth0'))
        info("*** h1 ARP table:\n")
        print(h1.cmd('arp -n'))
        info("*** h2 interface config:\n")
        print(h2.cmd('ifconfig h2-eth0'))
        
        info("*** Starting tcpdump on h2-eth0:\n")
        h2.cmd('tcpdump -i h2-eth0 -w h2_capture.pcap &')
        time.sleep(1)
        
        info("*** Pinging from h1 to h2:\n")
        print(h1.cmd('ping -c 10 10.0.1.2'))
        
        h2.cmd('pkill tcpdump')
        info("*** tcpdump output (check h2_capture.pcap manually):\n")
        
        info("*** Pinging h1 to h2 with net.ping:\n")
        print(net.ping([h1, h2]))
        
        CLI(net)
    finally:
        net.stop()

def main():
    setLogLevel('info')
    os.system('sudo pkill -f simple_switch')
    for tool in ['p4c', 'simple_switch', 'simple_switch_CLI']:
        if subprocess.run(['which', tool], capture_output=True).returncode != 0:
            print(f"ERROR: {tool} not found in PATH!")
            exit(1)
    compile_p4_program()
    setup_network()

if __name__ == '__main__':
    main()
# Out:
# Compiling P4 program...
# P4 compilation successful
# *** Creating network
# *** Adding hosts:
# h1 h2
# *** Adding switches:
# s1
# *** Adding links:
# (h1, s1) (h2, s1)
# *** Configuring hosts
# h1 h2
# *** Starting controller
#
# *** Starting 1 switches
# s1 *** Starting P4 switch s1: simple_switch --thrift-port 9090 --log-console --log-level trace --interface 0@s1-eth0 --interface 1@s1-eth1 forward.json &
# Calling target program-options parser
# [20:09:38.967] [bmv2] [D] [thread 152241] Set default default entry for table 'MyIngress.ipv4_lpm': MyIngress.drop -
# [20:09:38.967] [bmv2] [D] [thread 152241] Set default default entry for table 'MyIngress.ethernet_exact': MyIngress.broadcast -
# Adding interface s1-eth0 as port 0
# [20:09:38.970] [bmv2] [D] [thread 152241] Adding interface s1-eth0 as port 0
# Adding interface s1-eth1 as port 1
# [20:09:39.049] [bmv2] [D] [thread 152241] Adding interface s1-eth1 as port 1
# [20:09:39.085] [bmv2] [I] [thread 152241] Starting Thrift server on port 9090
# [20:09:39.085] [bmv2] [I] [thread 152241] Thrift server was started
# [20:09:39.225] [bmv2] [D] [thread 152248] [0.0] [cxt 0] Processing packet received on port 1
# [20:09:39.225] [bmv2] [D] [thread 152248] [0.0] [cxt 0] Parser 'parser': start
# [20:09:39.225] [bmv2] [D] [thread 152248] [0.0] [cxt 0] Parser 'parser' entering state 'start'
# [20:09:39.225] [bmv2] [D] [thread 152248] [0.0] [cxt 0] Extracting header 'ethernet'
# [20:09:39.225] [bmv2] [D] [thread 152248] [0.0] [cxt 0] Parser state 'start': key is 86dd
# [20:09:39.225] [bmv2] [T] [thread 152248] [0.0] [cxt 0] Bytes parsed: 14
# [20:09:39.225] [bmv2] [D] [thread 152248] [0.0] [cxt 0] Parser 'parser': end
# [20:09:39.225] [bmv2] [D] [thread 152248] [0.0] [cxt 0] Pipeline 'ingress': start
# [20:09:39.225] [bmv2] [T] [thread 152248] [0.0] [cxt 0] forward.p4(106) Condition "hdr.ipv4.isValid()" (node_2) is false
# [20:09:39.225] [bmv2] [T] [thread 152248] [0.0] [cxt 0] forward.p4(108) Condition "hdr.ethernet.isValid()" (node_4) is true
# [20:09:39.225] [bmv2] [T] [thread 152248] [0.0] [cxt 0] Applying table 'MyIngress.ethernet_exact'
# [20:09:39.225] [bmv2] [D] [thread 152248] [0.0] [cxt 0] Looking up key:
# * hdr.ethernet.dstAddr: 3333ff000102
#
# [20:09:39.225] [bmv2] [D] [thread 152248] [0.0] [cxt 0] Table 'MyIngress.ethernet_exact': miss
# [20:09:39.225] [bmv2] [D] [thread 152248] [0.0] [cxt 0] Action entry is MyIngress.broadcast -
# [20:09:39.225] [bmv2] [T] [thread 152248] [0.0] [cxt 0] Action MyIngress.broadcast
# [20:09:39.225] [bmv2] [T] [thread 152248] [0.0] [cxt 0] forward.p4(74) Primitive standard_meta.mcast_grp = 1
# [20:09:39.226] [bmv2] [D] [thread 152248] [0.0] [cxt 0] Pipeline 'ingress': end
# [20:09:39.226] [bmv2] [D] [thread 152248] [0.0] [cxt 0] Multicast requested for packet
# [20:09:39.226] [bmv2] [W] [thread 152248] Replication requested for mgid 1, which is not known to the PRE
# [20:09:39.321] [bmv2] [D] [thread 152248] [1.0] [cxt 0] Processing packet received on port 0
# [20:09:39.321] [bmv2] [D] [thread 152248] [1.0] [cxt 0] Parser 'parser': start
# [20:09:39.321] [bmv2] [D] [thread 152248] [1.0] [cxt 0] Parser 'parser' entering state 'start'
# [20:09:39.321] [bmv2] [D] [thread 152248] [1.0] [cxt 0] Extracting header 'ethernet'
# [20:09:39.321] [bmv2] [D] [thread 152248] [1.0] [cxt 0] Parser state 'start': key is 86dd
# [20:09:39.321] [bmv2] [T] [thread 152248] [1.0] [cxt 0] Bytes parsed: 14
# [20:09:39.321] [bmv2] [D] [thread 152248] [1.0] [cxt 0] Parser 'parser': end
# [20:09:39.321] [bmv2] [D] [thread 152248] [1.0] [cxt 0] Pipeline 'ingress': start
# [20:09:39.321] [bmv2] [T] [thread 152248] [1.0] [cxt 0] forward.p4(106) Condition "hdr.ipv4.isValid()" (node_2) is false
# [20:09:39.321] [bmv2] [T] [thread 152248] [1.0] [cxt 0] forward.p4(108) Condition "hdr.ethernet.isValid()" (node_4) is true
# [20:09:39.321] [bmv2] [T] [thread 152248] [1.0] [cxt 0] Applying table 'MyIngress.ethernet_exact'
# [20:09:39.321] [bmv2] [D] [thread 152248] [1.0] [cxt 0] Looking up key:
# * hdr.ethernet.dstAddr: 3333ff000101
#
# [20:09:39.321] [bmv2] [D] [thread 152248] [1.0] [cxt 0] Table 'MyIngress.ethernet_exact': miss
# [20:09:39.321] [bmv2] [D] [thread 152248] [1.0] [cxt 0] Action entry is MyIngress.broadcast -
# [20:09:39.321] [bmv2] [T] [thread 152248] [1.0] [cxt 0] Action MyIngress.broadcast
# [20:09:39.321] [bmv2] [T] [thread 152248] [1.0] [cxt 0] forward.p4(74) Primitive standard_meta.mcast_grp = 1
# [20:09:39.321] [bmv2] [D] [thread 152248] [1.0] [cxt 0] Pipeline 'ingress': end
# [20:09:39.321] [bmv2] [D] [thread 152248] [1.0] [cxt 0] Multicast requested for packet
# [20:09:39.321] [bmv2] [W] [thread 152248] Replication requested for mgid 1, which is not known to the PRE
# [20:09:39.417] [bmv2] [D] [thread 152248] [2.0] [cxt 0] Processing packet received on port 1
# [20:09:39.417] [bmv2] [D] [thread 152248] [2.0] [cxt 0] Parser 'parser': start
# [20:09:39.417] [bmv2] [D] [thread 152248] [2.0] [cxt 0] Parser 'parser' entering state 'start'
# [20:09:39.417] [bmv2] [D] [thread 152248] [2.0] [cxt 0] Extracting header 'ethernet'
# [20:09:39.417] [bmv2] [D] [thread 152248] [2.0] [cxt 0] Parser state 'start': key is 86dd
# [20:09:39.417] [bmv2] [T] [thread 152248] [2.0] [cxt 0] Bytes parsed: 14
# [20:09:39.417] [bmv2] [D] [thread 152248] [2.0] [cxt 0] Parser 'parser': end
# [20:09:39.417] [bmv2] [D] [thread 152248] [2.0] [cxt 0] Pipeline 'ingress': start
# [20:09:39.417] [bmv2] [T] [thread 152248] [2.0] [cxt 0] forward.p4(106) Condition "hdr.ipv4.isValid()" (node_2) is false
# [20:09:39.417] [bmv2] [T] [thread 152248] [2.0] [cxt 0] forward.p4(108) Condition "hdr.ethernet.isValid()" (node_4) is true
# [20:09:39.417] [bmv2] [T] [thread 152248] [2.0] [cxt 0] Applying table 'MyIngress.ethernet_exact'
# [20:09:39.417] [bmv2] [D] [thread 152248] [2.0] [cxt 0] Looking up key:
# * hdr.ethernet.dstAddr: 3333ffed32bd
#
# [20:09:39.417] [bmv2] [D] [thread 152248] [2.0] [cxt 0] Table 'MyIngress.ethernet_exact': miss
# [20:09:39.417] [bmv2] [D] [thread 152248] [2.0] [cxt 0] Action entry is MyIngress.broadcast -
# [20:09:39.417] [bmv2] [T] [thread 152248] [2.0] [cxt 0] Action MyIngress.broadcast
# [20:09:39.417] [bmv2] [T] [thread 152248] [2.0] [cxt 0] forward.p4(74) Primitive standard_meta.mcast_grp = 1
# [20:09:39.417] [bmv2] [D] [thread 152248] [2.0] [cxt 0] Pipeline 'ingress': end
# [20:09:39.417] [bmv2] [D] [thread 152248] [2.0] [cxt 0] Multicast requested for packet
# [20:09:39.417] [bmv2] [W] [thread 152248] Replication requested for mgid 1, which is not known to the PRE
# [20:09:39.513] [bmv2] [D] [thread 152248] [3.0] [cxt 0] Processing packet received on port 0
# [20:09:39.513] [bmv2] [D] [thread 152248] [3.0] [cxt 0] Parser 'parser': start
# [20:09:39.513] [bmv2] [D] [thread 152248] [3.0] [cxt 0] Parser 'parser' entering state 'start'
# [20:09:39.513] [bmv2] [D] [thread 152248] [3.0] [cxt 0] Extracting header 'ethernet'
# [20:09:39.513] [bmv2] [D] [thread 152248] [3.0] [cxt 0] Parser state 'start': key is 86dd
# [20:09:39.513] [bmv2] [T] [thread 152248] [3.0] [cxt 0] Bytes parsed: 14
# [20:09:39.513] [bmv2] [D] [thread 152248] [3.0] [cxt 0] Parser 'parser': end
# [20:09:39.513] [bmv2] [D] [thread 152248] [3.0] [cxt 0] Pipeline 'ingress': start
# [20:09:39.513] [bmv2] [T] [thread 152248] [3.0] [cxt 0] forward.p4(106) Condition "hdr.ipv4.isValid()" (node_2) is false
# [20:09:39.513] [bmv2] [T] [thread 152248] [3.0] [cxt 0] forward.p4(108) Condition "hdr.ethernet.isValid()" (node_4) is true
# [20:09:39.513] [bmv2] [T] [thread 152248] [3.0] [cxt 0] Applying table 'MyIngress.ethernet_exact'
# [20:09:39.513] [bmv2] [D] [thread 152248] [3.0] [cxt 0] Looking up key:
# * hdr.ethernet.dstAddr: 3333ffd4f49d
#
# [20:09:39.513] [bmv2] [D] [thread 152248] [3.0] [cxt 0] Table 'MyIngress.ethernet_exact': miss
# [20:09:39.513] [bmv2] [D] [thread 152248] [3.0] [cxt 0] Action entry is MyIngress.broadcast -
# [20:09:39.513] [bmv2] [T] [thread 152248] [3.0] [cxt 0] Action MyIngress.broadcast
# [20:09:39.513] [bmv2] [T] [thread 152248] [3.0] [cxt 0] forward.p4(74) Primitive standard_meta.mcast_grp = 1
# [20:09:39.513] [bmv2] [D] [thread 152248] [3.0] [cxt 0] Pipeline 'ingress': end
# [20:09:39.513] [bmv2] [D] [thread 152248] [3.0] [cxt 0] Multicast requested for packet
# [20:09:39.513] [bmv2] [W] [thread 152248] Replication requested for mgid 1, which is not known to the PRE
# [20:09:39.801] [bmv2] [D] [thread 152248] [4.0] [cxt 0] Processing packet received on port 0
# [20:09:39.801] [bmv2] [D] [thread 152248] [4.0] [cxt 0] Parser 'parser': start
# [20:09:39.801] [bmv2] [D] [thread 152248] [4.0] [cxt 0] Parser 'parser' entering state 'start'
# [20:09:39.801] [bmv2] [D] [thread 152248] [4.0] [cxt 0] Extracting header 'ethernet'
# [20:09:39.801] [bmv2] [D] [thread 152248] [4.0] [cxt 0] Parser state 'start': key is 86dd
# [20:09:39.801] [bmv2] [T] [thread 152248] [4.0] [cxt 0] Bytes parsed: 14
# [20:09:39.801] [bmv2] [D] [thread 152248] [4.0] [cxt 0] Parser 'parser': end
# [20:09:39.801] [bmv2] [D] [thread 152248] [4.0] [cxt 0] Pipeline 'ingress': start
# [20:09:39.801] [bmv2] [T] [thread 152248] [4.0] [cxt 0] forward.p4(106) Condition "hdr.ipv4.isValid()" (node_2) is false
# [20:09:39.801] [bmv2] [T] [thread 152248] [4.0] [cxt 0] forward.p4(108) Condition "hdr.ethernet.isValid()" (node_4) is true
# [20:09:39.801] [bmv2] [T] [thread 152248] [4.0] [cxt 0] Applying table 'MyIngress.ethernet_exact'
# [20:09:39.801] [bmv2] [D] [thread 152248] [4.0] [cxt 0] Looking up key:
# * hdr.ethernet.dstAddr: 333300000016
#
# [20:09:39.801] [bmv2] [D] [thread 152248] [4.0] [cxt 0] Table 'MyIngress.ethernet_exact': miss
# [20:09:39.801] [bmv2] [D] [thread 152248] [4.0] [cxt 0] Action entry is MyIngress.broadcast -
# [20:09:39.801] [bmv2] [T] [thread 152248] [4.0] [cxt 0] Action MyIngress.broadcast
# [20:09:39.801] [bmv2] [T] [thread 152248] [4.0] [cxt 0] forward.p4(74) Primitive standard_meta.mcast_grp = 1
# [20:09:39.801] [bmv2] [D] [thread 152248] [4.0] [cxt 0] Pipeline 'ingress': end
# [20:09:39.801] [bmv2] [D] [thread 152248] [4.0] [cxt 0] Multicast requested for packet
# [20:09:39.801] [bmv2] [W] [thread 152248] Replication requested for mgid 1, which is not known to the PRE
# [20:09:39.865] [bmv2] [D] [thread 152248] [5.0] [cxt 0] Processing packet received on port 1
# [20:09:39.865] [bmv2] [D] [thread 152248] [5.0] [cxt 0] Parser 'parser': start
# [20:09:39.865] [bmv2] [D] [thread 152248] [5.0] [cxt 0] Parser 'parser' entering state 'start'
# [20:09:39.865] [bmv2] [D] [thread 152248] [5.0] [cxt 0] Extracting header 'ethernet'
# [20:09:39.865] [bmv2] [D] [thread 152248] [5.0] [cxt 0] Parser state 'start': key is 86dd
# [20:09:39.865] [bmv2] [T] [thread 152248] [5.0] [cxt 0] Bytes parsed: 14
# [20:09:39.865] [bmv2] [D] [thread 152248] [5.0] [cxt 0] Parser 'parser': end
# [20:09:39.865] [bmv2] [D] [thread 152248] [5.0] [cxt 0] Pipeline 'ingress': start
# [20:09:39.865] [bmv2] [T] [thread 152248] [5.0] [cxt 0] forward.p4(106) Condition "hdr.ipv4.isValid()" (node_2) is false
# [20:09:39.865] [bmv2] [T] [thread 152248] [5.0] [cxt 0] forward.p4(108) Condition "hdr.ethernet.isValid()" (node_4) is true
# [20:09:39.865] [bmv2] [T] [thread 152248] [5.0] [cxt 0] Applying table 'MyIngress.ethernet_exact'
# [20:09:39.865] [bmv2] [D] [thread 152248] [5.0] [cxt 0] Looking up key:
# * hdr.ethernet.dstAddr: 333300000016
#
# [20:09:39.865] [bmv2] [D] [thread 152248] [5.0] [cxt 0] Table 'MyIngress.ethernet_exact': miss
# [20:09:39.865] [bmv2] [D] [thread 152248] [5.0] [cxt 0] Action entry is MyIngress.broadcast -
# [20:09:39.865] [bmv2] [T] [thread 152248] [5.0] [cxt 0] Action MyIngress.broadcast
# [20:09:39.865] [bmv2] [T] [thread 152248] [5.0] [cxt 0] forward.p4(74) Primitive standard_meta.mcast_grp = 1
# [20:09:39.865] [bmv2] [D] [thread 152248] [5.0] [cxt 0] Pipeline 'ingress': end
# [20:09:39.865] [bmv2] [D] [thread 152248] [5.0] [cxt 0] Multicast requested for packet
# [20:09:39.865] [bmv2] [W] [thread 152248] Replication requested for mgid 1, which is not known to the PRE
# [20:09:40.249] [bmv2] [D] [thread 152248] [6.0] [cxt 0] Processing packet received on port 1
# [20:09:40.249] [bmv2] [D] [thread 152248] [6.0] [cxt 0] Parser 'parser': start
# [20:09:40.249] [bmv2] [D] [thread 152248] [6.0] [cxt 0] Parser 'parser' entering state 'start'
# [20:09:40.249] [bmv2] [D] [thread 152248] [6.0] [cxt 0] Extracting header 'ethernet'
# [20:09:40.249] [bmv2] [D] [thread 152248] [6.0] [cxt 0] Parser state 'start': key is 86dd
# [20:09:40.249] [bmv2] [T] [thread 152248] [6.0] [cxt 0] Bytes parsed: 14
# [20:09:40.249] [bmv2] [D] [thread 152248] [6.0] [cxt 0] Parser 'parser': end
# [20:09:40.249] [bmv2] [D] [thread 152248] [6.0] [cxt 0] Pipeline 'ingress': start
# [20:09:40.249] [bmv2] [T] [thread 152248] [6.0] [cxt 0] forward.p4(106) Condition "hdr.ipv4.isValid()" (node_2) is false
# [20:09:40.249] [bmv2] [T] [thread 152248] [6.0] [cxt 0] forward.p4(108) Condition "hdr.ethernet.isValid()" (node_4) is true
# [20:09:40.249] [bmv2] [T] [thread 152248] [6.0] [cxt 0] Applying table 'MyIngress.ethernet_exact'
# [20:09:40.249] [bmv2] [D] [thread 152248] [6.0] [cxt 0] Looking up key:
# * hdr.ethernet.dstAddr: 333300000016
#
# [20:09:40.249] [bmv2] [D] [thread 152248] [6.0] [cxt 0] Table 'MyIngress.ethernet_exact': miss
# [20:09:40.249] [bmv2] [D] [thread 152248] [6.0] [cxt 0] Action entry is MyIngress.broadcast -
# [20:09:40.249] [bmv2] [T] [thread 152248] [6.0] [cxt 0] Action MyIngress.broadcast
# [20:09:40.249] [bmv2] [T] [thread 152248] [6.0] [cxt 0] forward.p4(74) Primitive standard_meta.mcast_grp = 1
# [20:09:40.249] [bmv2] [D] [thread 152248] [6.0] [cxt 0] Pipeline 'ingress': end
# [20:09:40.249] [bmv2] [D] [thread 152248] [6.0] [cxt 0] Multicast requested for packet
# [20:09:40.249] [bmv2] [W] [thread 152248] Replication requested for mgid 1, which is not known to the PRE
# [20:09:40.249] [bmv2] [D] [thread 152248] [7.0] [cxt 0] Processing packet received on port 1
# [20:09:40.249] [bmv2] [D] [thread 152248] [7.0] [cxt 0] Parser 'parser': start
# [20:09:40.249] [bmv2] [D] [thread 152248] [7.0] [cxt 0] Parser 'parser' entering state 'start'
# [20:09:40.249] [bmv2] [D] [thread 152248] [7.0] [cxt 0] Extracting header 'ethernet'
# [20:09:40.249] [bmv2] [D] [thread 152248] [7.0] [cxt 0] Parser state 'start': key is 86dd
# [20:09:40.249] [bmv2] [T] [thread 152248] [7.0] [cxt 0] Bytes parsed: 14
# [20:09:40.249] [bmv2] [D] [thread 152248] [7.0] [cxt 0] Parser 'parser': end
# [20:09:40.249] [bmv2] [D] [thread 152248] [7.0] [cxt 0] Pipeline 'ingress': start
# [20:09:40.249] [bmv2] [T] [thread 152248] [7.0] [cxt 0] forward.p4(106) Condition "hdr.ipv4.isValid()" (node_2) is false
# [20:09:40.249] [bmv2] [T] [thread 152248] [7.0] [cxt 0] forward.p4(108) Condition "hdr.ethernet.isValid()" (node_4) is true
# [20:09:40.249] [bmv2] [T] [thread 152248] [7.0] [cxt 0] Applying table 'MyIngress.ethernet_exact'
# [20:09:40.249] [bmv2] [D] [thread 152248] [7.0] [cxt 0] Looking up key:
# * hdr.ethernet.dstAddr: 333300000002
#
# [20:09:40.249] [bmv2] [D] [thread 152248] [7.0] [cxt 0] Table 'MyIngress.ethernet_exact': miss
# [20:09:40.249] [bmv2] [D] [thread 152248] [7.0] [cxt 0] Action entry is MyIngress.broadcast -
# [20:09:40.249] [bmv2] [T] [thread 152248] [7.0] [cxt 0] Action MyIngress.broadcast
# [20:09:40.249] [bmv2] [T] [thread 152248] [7.0] [cxt 0] forward.p4(74) Primitive standard_meta.mcast_grp = 1
# [20:09:40.249] [bmv2] [D] [thread 152248] [7.0] [cxt 0] Pipeline 'ingress': end
# [20:09:40.249] [bmv2] [D] [thread 152248] [7.0] [cxt 0] Multicast requested for packet
# [20:09:40.250] [bmv2] [W] [thread 152248] Replication requested for mgid 1, which is not known to the PRE
# [20:09:40.345] [bmv2] [D] [thread 152248] [8.0] [cxt 0] Processing packet received on port 0
# [20:09:40.345] [bmv2] [D] [thread 152248] [8.0] [cxt 0] Parser 'parser': start
# [20:09:40.345] [bmv2] [D] [thread 152248] [8.0] [cxt 0] Parser 'parser' entering state 'start'
# [20:09:40.345] [bmv2] [D] [thread 152248] [8.0] [cxt 0] Extracting header 'ethernet'
# [20:09:40.345] [bmv2] [D] [thread 152248] [8.0] [cxt 0] Parser state 'start': key is 86dd
# [20:09:40.345] [bmv2] [T] [thread 152248] [8.0] [cxt 0] Bytes parsed: 14
# [20:09:40.345] [bmv2] [D] [thread 152248] [8.0] [cxt 0] Parser 'parser': end
# [20:09:40.345] [bmv2] [D] [thread 152248] [8.0] [cxt 0] Pipeline 'ingress': start
# [20:09:40.345] [bmv2] [T] [thread 152248] [8.0] [cxt 0] forward.p4(106) Condition "hdr.ipv4.isValid()" (node_2) is false
# [20:09:40.345] [bmv2] [T] [thread 152248] [8.0] [cxt 0] forward.p4(108) Condition "hdr.ethernet.isValid()" (node_4) is true
# [20:09:40.345] [bmv2] [T] [thread 152248] [8.0] [cxt 0] Applying table 'MyIngress.ethernet_exact'
# [20:09:40.345] [bmv2] [D] [thread 152248] [8.0] [cxt 0] Looking up key:
# * hdr.ethernet.dstAddr: 333300000016
#
# [20:09:40.345] [bmv2] [D] [thread 152248] [8.0] [cxt 0] Table 'MyIngress.ethernet_exact': miss
# [20:09:40.345] [bmv2] [D] [thread 152248] [8.0] [cxt 0] Action entry is MyIngress.broadcast -
# [20:09:40.345] [bmv2] [T] [thread 152248] [8.0] [cxt 0] Action MyIngress.broadcast
# [20:09:40.345] [bmv2] [T] [thread 152248] [8.0] [cxt 0] forward.p4(74) Primitive standard_meta.mcast_grp = 1
# [20:09:40.345] [bmv2] [D] [thread 152248] [8.0] [cxt 0] Pipeline 'ingress': end
# [20:09:40.345] [bmv2] [D] [thread 152248] [8.0] [cxt 0] Multicast requested for packet
# [20:09:40.345] [bmv2] [W] [thread 152248] Replication requested for mgid 1, which is not known to the PRE
# [20:09:40.345] [bmv2] [D] [thread 152248] [9.0] [cxt 0] Processing packet received on port 0
# [20:09:40.345] [bmv2] [D] [thread 152248] [9.0] [cxt 0] Parser 'parser': start
# [20:09:40.345] [bmv2] [D] [thread 152248] [9.0] [cxt 0] Parser 'parser' entering state 'start'
# [20:09:40.345] [bmv2] [D] [thread 152248] [9.0] [cxt 0] Extracting header 'ethernet'
# [20:09:40.345] [bmv2] [D] [thread 152248] [9.0] [cxt 0] Parser state 'start': key is 86dd
# [20:09:40.345] [bmv2] [T] [thread 152248] [9.0] [cxt 0] Bytes parsed: 14
# [20:09:40.345] [bmv2] [D] [thread 152248] [9.0] [cxt 0] Parser 'parser': end
# [20:09:40.345] [bmv2] [D] [thread 152248] [9.0] [cxt 0] Pipeline 'ingress': start
# [20:09:40.345] [bmv2] [T] [thread 152248] [9.0] [cxt 0] forward.p4(106) Condition "hdr.ipv4.isValid()" (node_2) is false
# [20:09:40.345] [bmv2] [T] [thread 152248] [9.0] [cxt 0] forward.p4(108) Condition "hdr.ethernet.isValid()" (node_4) is true
# [20:09:40.345] [bmv2] [T] [thread 152248] [9.0] [cxt 0] Applying table 'MyIngress.ethernet_exact'
# [20:09:40.345] [bmv2] [D] [thread 152248] [9.0] [cxt 0] Looking up key:
# * hdr.ethernet.dstAddr: 333300000002
#
# [20:09:40.345] [bmv2] [D] [thread 152248] [9.0] [cxt 0] Table 'MyIngress.ethernet_exact': miss
# [20:09:40.345] [bmv2] [D] [thread 152248] [9.0] [cxt 0] Action entry is MyIngress.broadcast -
# [20:09:40.345] [bmv2] [T] [thread 152248] [9.0] [cxt 0] Action MyIngress.broadcast
# [20:09:40.345] [bmv2] [T] [thread 152248] [9.0] [cxt 0] forward.p4(74) Primitive standard_meta.mcast_grp = 1
# [20:09:40.346] [bmv2] [D] [thread 152248] [9.0] [cxt 0] Pipeline 'ingress': end
# [20:09:40.346] [bmv2] [D] [thread 152248] [9.0] [cxt 0] Multicast requested for packet
# [20:09:40.346] [bmv2] [W] [thread 152248] Replication requested for mgid 1, which is not known to the PRE
# [20:09:40.441] [bmv2] [D] [thread 152248] [10.0] [cxt 0] Processing packet received on port 1
# [20:09:40.441] [bmv2] [D] [thread 152248] [10.0] [cxt 0] Parser 'parser': start
# [20:09:40.441] [bmv2] [D] [thread 152248] [10.0] [cxt 0] Parser 'parser' entering state 'start'
# [20:09:40.441] [bmv2] [D] [thread 152248] [10.0] [cxt 0] Extracting header 'ethernet'
# [20:09:40.441] [bmv2] [D] [thread 152248] [10.0] [cxt 0] Parser state 'start': key is 86dd
# [20:09:40.441] [bmv2] [T] [thread 152248] [10.0] [cxt 0] Bytes parsed: 14
# [20:09:40.441] [bmv2] [D] [thread 152248] [10.0] [cxt 0] Parser 'parser': end
# [20:09:40.441] [bmv2] [D] [thread 152248] [10.0] [cxt 0] Pipeline 'ingress': start
# [20:09:40.441] [bmv2] [T] [thread 152248] [10.0] [cxt 0] forward.p4(106) Condition "hdr.ipv4.isValid()" (node_2) is false
# [20:09:40.441] [bmv2] [T] [thread 152248] [10.0] [cxt 0] forward.p4(108) Condition "hdr.ethernet.isValid()" (node_4) is true
# [20:09:40.441] [bmv2] [T] [thread 152248] [10.0] [cxt 0] Applying table 'MyIngress.ethernet_exact'
# [20:09:40.441] [bmv2] [D] [thread 152248] [10.0] [cxt 0] Looking up key:
# * hdr.ethernet.dstAddr: 333300000016
#
# [20:09:40.441] [bmv2] [D] [thread 152248] [10.0] [cxt 0] Table 'MyIngress.ethernet_exact': miss
# [20:09:40.441] [bmv2] [D] [thread 152248] [10.0] [cxt 0] Action entry is MyIngress.broadcast -
# [20:09:40.441] [bmv2] [T] [thread 152248] [10.0] [cxt 0] Action MyIngress.broadcast
# [20:09:40.441] [bmv2] [T] [thread 152248] [10.0] [cxt 0] forward.p4(74) Primitive standard_meta.mcast_grp = 1
# [20:09:40.441] [bmv2] [D] [thread 152248] [10.0] [cxt 0] Pipeline 'ingress': end
# [20:09:40.441] [bmv2] [D] [thread 152248] [10.0] [cxt 0] Multicast requested for packet
# [20:09:40.441] [bmv2] [W] [thread 152248] Replication requested for mgid 1, which is not known to the PRE
# [20:09:40.441] [bmv2] [D] [thread 152248] [11.0] [cxt 0] Processing packet received on port 1
# [20:09:40.441] [bmv2] [D] [thread 152248] [11.0] [cxt 0] Parser 'parser': start
# [20:09:40.441] [bmv2] [D] [thread 152248] [11.0] [cxt 0] Parser 'parser' entering state 'start'
# [20:09:40.441] [bmv2] [D] [thread 152248] [11.0] [cxt 0] Extracting header 'ethernet'
# [20:09:40.441] [bmv2] [D] [thread 152248] [11.0] [cxt 0] Parser state 'start': key is 86dd
# [20:09:40.441] [bmv2] [T] [thread 152248] [11.0] [cxt 0] Bytes parsed: 14
# [20:09:40.441] [bmv2] [D] [thread 152248] [11.0] [cxt 0] Parser 'parser': end
# [20:09:40.441] [bmv2] [D] [thread 152248] [11.0] [cxt 0] Pipeline 'ingress': start
# [20:09:40.441] [bmv2] [T] [thread 152248] [11.0] [cxt 0] forward.p4(106) Condition "hdr.ipv4.isValid()" (node_2) is false
# [20:09:40.441] [bmv2] [T] [thread 152248] [11.0] [cxt 0] forward.p4(108) Condition "hdr.ethernet.isValid()" (node_4) is true
# [20:09:40.441] [bmv2] [T] [thread 152248] [11.0] [cxt 0] Applying table 'MyIngress.ethernet_exact'
# [20:09:40.441] [bmv2] [D] [thread 152248] [11.0] [cxt 0] Looking up key:
# * hdr.ethernet.dstAddr: 333300000002
#
# [20:09:40.441] [bmv2] [D] [thread 152248] [11.0] [cxt 0] Table 'MyIngress.ethernet_exact': miss
# [20:09:40.441] [bmv2] [D] [thread 152248] [11.0] [cxt 0] Action entry is MyIngress.broadcast -
# [20:09:40.441] [bmv2] [T] [thread 152248] [11.0] [cxt 0] Action MyIngress.broadcast
# [20:09:40.442] [bmv2] [T] [thread 152248] [11.0] [cxt 0] forward.p4(74) Primitive standard_meta.mcast_grp = 1
# [20:09:40.442] [bmv2] [D] [thread 152248] [11.0] [cxt 0] Pipeline 'ingress': end
# [20:09:40.442] [bmv2] [D] [thread 152248] [11.0] [cxt 0] Multicast requested for packet
# [20:09:40.442] [bmv2] [W] [thread 152248] Replication requested for mgid 1, which is not known to the PRE
# [20:09:40.537] [bmv2] [D] [thread 152248] [12.0] [cxt 0] Processing packet received on port 0
# [20:09:40.537] [bmv2] [D] [thread 152248] [12.0] [cxt 0] Parser 'parser': start
# [20:09:40.537] [bmv2] [D] [thread 152248] [12.0] [cxt 0] Parser 'parser' entering state 'start'
# [20:09:40.537] [bmv2] [D] [thread 152248] [12.0] [cxt 0] Extracting header 'ethernet'
# [20:09:40.537] [bmv2] [D] [thread 152248] [12.0] [cxt 0] Parser state 'start': key is 86dd
# [20:09:40.537] [bmv2] [T] [thread 152248] [12.0] [cxt 0] Bytes parsed: 14
# [20:09:40.537] [bmv2] [D] [thread 152248] [12.0] [cxt 0] Parser 'parser': end
# [20:09:40.537] [bmv2] [D] [thread 152248] [12.0] [cxt 0] Pipeline 'ingress': start
# [20:09:40.537] [bmv2] [T] [thread 152248] [12.0] [cxt 0] forward.p4(106) Condition "hdr.ipv4.isValid()" (node_2) is false
# [20:09:40.537] [bmv2] [T] [thread 152248] [12.0] [cxt 0] forward.p4(108) Condition "hdr.ethernet.isValid()" (node_4) is true
# [20:09:40.537] [bmv2] [T] [thread 152248] [12.0] [cxt 0] Applying table 'MyIngress.ethernet_exact'
# [20:09:40.537] [bmv2] [D] [thread 152248] [12.0] [cxt 0] Looking up key:
# * hdr.ethernet.dstAddr: 333300000016
#
# [20:09:40.537] [bmv2] [D] [thread 152248] [12.0] [cxt 0] Table 'MyIngress.ethernet_exact': miss
# [20:09:40.537] [bmv2] [D] [thread 152248] [12.0] [cxt 0] Action entry is MyIngress.broadcast -
# [20:09:40.537] [bmv2] [T] [thread 152248] [12.0] [cxt 0] Action MyIngress.broadcast
# [20:09:40.537] [bmv2] [T] [thread 152248] [12.0] [cxt 0] forward.p4(74) Primitive standard_meta.mcast_grp = 1
# [20:09:40.537] [bmv2] [D] [thread 152248] [12.0] [cxt 0] Pipeline 'ingress': end
# [20:09:40.537] [bmv2] [D] [thread 152248] [12.0] [cxt 0] Multicast requested for packet
# [20:09:40.537] [bmv2] [W] [thread 152248] Replication requested for mgid 1, which is not known to the PRE
# [20:09:40.537] [bmv2] [D] [thread 152248] [13.0] [cxt 0] Processing packet received on port 0
# [20:09:40.537] [bmv2] [D] [thread 152248] [13.0] [cxt 0] Parser 'parser': start
# [20:09:40.537] [bmv2] [D] [thread 152248] [13.0] [cxt 0] Parser 'parser' entering state 'start'
# [20:09:40.537] [bmv2] [D] [thread 152248] [13.0] [cxt 0] Extracting header 'ethernet'
# [20:09:40.537] [bmv2] [D] [thread 152248] [13.0] [cxt 0] Parser state 'start': key is 86dd
# [20:09:40.537] [bmv2] [T] [thread 152248] [13.0] [cxt 0] Bytes parsed: 14
# [20:09:40.537] [bmv2] [D] [thread 152248] [13.0] [cxt 0] Parser 'parser': end
# [20:09:40.537] [bmv2] [D] [thread 152248] [13.0] [cxt 0] Pipeline 'ingress': start
# [20:09:40.537] [bmv2] [T] [thread 152248] [13.0] [cxt 0] forward.p4(106) Condition "hdr.ipv4.isValid()" (node_2) is false
# [20:09:40.537] [bmv2] [T] [thread 152248] [13.0] [cxt 0] forward.p4(108) Condition "hdr.ethernet.isValid()" (node_4) is true
# [20:09:40.537] [bmv2] [T] [thread 152248] [13.0] [cxt 0] Applying table 'MyIngress.ethernet_exact'
# [20:09:40.537] [bmv2] [D] [thread 152248] [13.0] [cxt 0] Looking up key:
# * hdr.ethernet.dstAddr: 333300000002
#
# [20:09:40.537] [bmv2] [D] [thread 152248] [13.0] [cxt 0] Table 'MyIngress.ethernet_exact': miss
# [20:09:40.537] [bmv2] [D] [thread 152248] [13.0] [cxt 0] Action entry is MyIngress.broadcast -
# [20:09:40.537] [bmv2] [T] [thread 152248] [13.0] [cxt 0] Action MyIngress.broadcast
# [20:09:40.537] [bmv2] [T] [thread 152248] [13.0] [cxt 0] forward.p4(74) Primitive standard_meta.mcast_grp = 1
# [20:09:40.537] [bmv2] [D] [thread 152248] [13.0] [cxt 0] Pipeline 'ingress': end
# [20:09:40.537] [bmv2] [D] [thread 152248] [13.0] [cxt 0] Multicast requested for packet
# [20:09:40.537] [bmv2] [W] [thread 152248] Replication requested for mgid 1, which is not known to the PRE
# [20:09:40.793] [bmv2] [D] [thread 152248] [14.0] [cxt 0] Processing packet received on port 0
# [20:09:40.793] [bmv2] [D] [thread 152248] [14.0] [cxt 0] Parser 'parser': start
# [20:09:40.793] [bmv2] [D] [thread 152248] [14.0] [cxt 0] Parser 'parser' entering state 'start'
# [20:09:40.793] [bmv2] [D] [thread 152248] [14.0] [cxt 0] Extracting header 'ethernet'
# [20:09:40.793] [bmv2] [D] [thread 152248] [14.0] [cxt 0] Parser state 'start': key is 86dd
# [20:09:40.793] [bmv2] [T] [thread 152248] [14.0] [cxt 0] Bytes parsed: 14
# [20:09:40.793] [bmv2] [D] [thread 152248] [14.0] [cxt 0] Parser 'parser': end
# [20:09:40.793] [bmv2] [D] [thread 152248] [14.0] [cxt 0] Pipeline 'ingress': start
# [20:09:40.793] [bmv2] [T] [thread 152248] [14.0] [cxt 0] forward.p4(106) Condition "hdr.ipv4.isValid()" (node_2) is false
# [20:09:40.793] [bmv2] [T] [thread 152248] [14.0] [cxt 0] forward.p4(108) Condition "hdr.ethernet.isValid()" (node_4) is true
# [20:09:40.793] [bmv2] [T] [thread 152248] [14.0] [cxt 0] Applying table 'MyIngress.ethernet_exact'
# [20:09:40.793] [bmv2] [D] [thread 152248] [14.0] [cxt 0] Looking up key:
# * hdr.ethernet.dstAddr: 333300000016
#
# [20:09:40.793] [bmv2] [D] [thread 152248] [14.0] [cxt 0] Table 'MyIngress.ethernet_exact': miss
# [20:09:40.793] [bmv2] [D] [thread 152248] [14.0] [cxt 0] Action entry is MyIngress.broadcast -
# [20:09:40.793] [bmv2] [T] [thread 152248] [14.0] [cxt 0] Action MyIngress.broadcast
# [20:09:40.793] [bmv2] [T] [thread 152248] [14.0] [cxt 0] forward.p4(74) Primitive standard_meta.mcast_grp = 1
# [20:09:40.793] [bmv2] [D] [thread 152248] [14.0] [cxt 0] Pipeline 'ingress': end
# [20:09:40.793] [bmv2] [D] [thread 152248] [14.0] [cxt 0] Multicast requested for packet
# [20:09:40.793] [bmv2] [W] [thread 152248] Replication requested for mgid 1, which is not known to the PRE
# [20:09:41.241] [bmv2] [D] [thread 152248] [15.0] [cxt 0] Processing packet received on port 0
# [20:09:41.241] [bmv2] [D] [thread 152248] [15.0] [cxt 0] Parser 'parser': start
# [20:09:41.241] [bmv2] [D] [thread 152248] [15.0] [cxt 0] Parser 'parser' entering state 'start'
# [20:09:41.241] [bmv2] [D] [thread 152248] [15.0] [cxt 0] Extracting header 'ethernet'
# [20:09:41.241] [bmv2] [D] [thread 152248] [15.0] [cxt 0] Parser state 'start': key is 86dd
# [20:09:41.241] [bmv2] [T] [thread 152248] [15.0] [cxt 0] Bytes parsed: 14
# [20:09:41.241] [bmv2] [D] [thread 152248] [15.0] [cxt 0] Parser 'parser': end
# [20:09:41.241] [bmv2] [D] [thread 152248] [15.0] [cxt 0] Pipeline 'ingress': start
# [20:09:41.241] [bmv2] [T] [thread 152248] [15.0] [cxt 0] forward.p4(106) Condition "hdr.ipv4.isValid()" (node_2) is false
# [20:09:41.241] [bmv2] [T] [thread 152248] [15.0] [cxt 0] forward.p4(108) Condition "hdr.ethernet.isValid()" (node_4) is true
# [20:09:41.241] [bmv2] [T] [thread 152248] [15.0] [cxt 0] Applying table 'MyIngress.ethernet_exact'
# [20:09:41.241] [bmv2] [D] [thread 152248] [15.0] [cxt 0] Looking up key:
# * hdr.ethernet.dstAddr: 333300000016
#
# [20:09:41.241] [bmv2] [D] [thread 152248] [15.0] [cxt 0] Table 'MyIngress.ethernet_exact': miss
# [20:09:41.241] [bmv2] [D] [thread 152248] [15.0] [cxt 0] Action entry is MyIngress.broadcast -
# [20:09:41.241] [bmv2] [T] [thread 152248] [15.0] [cxt 0] Action MyIngress.broadcast
# [20:09:41.241] [bmv2] [T] [thread 152248] [15.0] [cxt 0] forward.p4(74) Primitive standard_meta.mcast_grp = 1
# [20:09:41.241] [bmv2] [D] [thread 152248] [15.0] [cxt 0] Pipeline 'ingress': end
# [20:09:41.241] [bmv2] [D] [thread 152248] [15.0] [cxt 0] Multicast requested for packet
# [20:09:41.241] [bmv2] [W] [thread 152248] Replication requested for mgid 1, which is not known to the PRE
# [20:09:41.241] [bmv2] [D] [thread 152248] [16.0] [cxt 0] Processing packet received on port 1
# [20:09:41.241] [bmv2] [D] [thread 152248] [16.0] [cxt 0] Parser 'parser': start
# [20:09:41.241] [bmv2] [D] [thread 152248] [16.0] [cxt 0] Parser 'parser' entering state 'start'
# [20:09:41.241] [bmv2] [D] [thread 152248] [16.0] [cxt 0] Extracting header 'ethernet'
# [20:09:41.241] [bmv2] [D] [thread 152248] [16.0] [cxt 0] Parser state 'start': key is 86dd
# [20:09:41.241] [bmv2] [T] [thread 152248] [16.0] [cxt 0] Bytes parsed: 14
# [20:09:41.241] [bmv2] [D] [thread 152248] [16.0] [cxt 0] Parser 'parser': end
# [20:09:41.241] [bmv2] [D] [thread 152248] [16.0] [cxt 0] Pipeline 'ingress': start
# [20:09:41.241] [bmv2] [T] [thread 152248] [16.0] [cxt 0] forward.p4(106) Condition "hdr.ipv4.isValid()" (node_2) is false
# [20:09:41.241] [bmv2] [T] [thread 152248] [16.0] [cxt 0] forward.p4(108) Condition "hdr.ethernet.isValid()" (node_4) is true
# [20:09:41.241] [bmv2] [T] [thread 152248] [16.0] [cxt 0] Applying table 'MyIngress.ethernet_exact'
# [20:09:41.241] [bmv2] [D] [thread 152248] [16.0] [cxt 0] Looking up key:
# * hdr.ethernet.dstAddr: 333300000016
#
# [20:09:41.241] [bmv2] [D] [thread 152248] [16.0] [cxt 0] Table 'MyIngress.ethernet_exact': miss
# [20:09:41.241] [bmv2] [D] [thread 152248] [16.0] [cxt 0] Action entry is MyIngress.broadcast -
# [20:09:41.241] [bmv2] [T] [thread 152248] [16.0] [cxt 0] Action MyIngress.broadcast
# [20:09:41.241] [bmv2] [T] [thread 152248] [16.0] [cxt 0] forward.p4(74) Primitive standard_meta.mcast_grp = 1
# [20:09:41.241] [bmv2] [D] [thread 152248] [16.0] [cxt 0] Pipeline 'ingress': end
# [20:09:41.241] [bmv2] [D] [thread 152248] [16.0] [cxt 0] Multicast requested for packet
# [20:09:41.241] [bmv2] [W] [thread 152248] Replication requested for mgid 1, which is not known to the PRE
# [20:09:41.305] [bmv2] [D] [thread 152248] [17.0] [cxt 0] Processing packet received on port 1
# [20:09:41.305] [bmv2] [D] [thread 152248] [17.0] [cxt 0] Parser 'parser': start
# [20:09:41.305] [bmv2] [D] [thread 152248] [17.0] [cxt 0] Parser 'parser' entering state 'start'
# [20:09:41.305] [bmv2] [D] [thread 152248] [17.0] [cxt 0] Extracting header 'ethernet'
# [20:09:41.305] [bmv2] [D] [thread 152248] [17.0] [cxt 0] Parser state 'start': key is 86dd
# [20:09:41.305] [bmv2] [T] [thread 152248] [17.0] [cxt 0] Bytes parsed: 14
# [20:09:41.305] [bmv2] [D] [thread 152248] [17.0] [cxt 0] Parser 'parser': end
# [20:09:41.305] [bmv2] [D] [thread 152248] [17.0] [cxt 0] Pipeline 'ingress': start
# [20:09:41.305] [bmv2] [T] [thread 152248] [17.0] [cxt 0] forward.p4(106) Condition "hdr.ipv4.isValid()" (node_2) is false
# [20:09:41.305] [bmv2] [T] [thread 152248] [17.0] [cxt 0] forward.p4(108) Condition "hdr.ethernet.isValid()" (node_4) is true
# [20:09:41.305] [bmv2] [T] [thread 152248] [17.0] [cxt 0] Applying table 'MyIngress.ethernet_exact'
# [20:09:41.305] [bmv2] [D] [thread 152248] [17.0] [cxt 0] Looking up key:
# * hdr.ethernet.dstAddr: 333300000016
#
# [20:09:41.305] [bmv2] [D] [thread 152248] [17.0] [cxt 0] Table 'MyIngress.ethernet_exact': miss
# [20:09:41.305] [bmv2] [D] [thread 152248] [17.0] [cxt 0] Action entry is MyIngress.broadcast -
# [20:09:41.305] [bmv2] [T] [thread 152248] [17.0] [cxt 0] Action MyIngress.broadcast
# [20:09:41.305] [bmv2] [T] [thread 152248] [17.0] [cxt 0] forward.p4(74) Primitive standard_meta.mcast_grp = 1
# [20:09:41.305] [bmv2] [D] [thread 152248] [17.0] [cxt 0] Pipeline 'ingress': end
# [20:09:41.305] [bmv2] [D] [thread 152248] [17.0] [cxt 0] Multicast requested for packet
# [20:09:41.305] [bmv2] [W] [thread 152248] Replication requested for mgid 1, which is not known to the PRE
# *** h1 interface config:
# *** h1 ARP table:
# *** h2 interface config:
# *** Starting tcpdump on h2-eth0:
# [20:09:44.018] [bmv2] [T] [thread 152256] bm_get_config
# [20:09:44.019] [bmv2] [T] [thread 152256] bm_mc_mgrp_create
# [20:09:44.019] [bmv2] [D] [thread 152256] mgrp node created for mgid 1
# [20:09:44.019] [bmv2] [T] [thread 152256] bm_mc_node_create
# [20:09:44.019] [bmv2] [D] [thread 152256] node created for rid 0
# [20:09:44.019] [bmv2] [T] [thread 152256] bm_mc_node_associate
# [20:09:44.019] [bmv2] [D] [thread 152256] node associated with mgid 1
# [20:09:44.088] [bmv2] [T] [thread 152258] bm_get_config
# [20:09:44.089] [bmv2] [T] [thread 152258] bm_table_add_entry
# [20:09:44.089] [bmv2] [D] [thread 152258] Entry 0 added to table 'MyIngress.ipv4_lpm'
# [20:09:44.089] [bmv2] [D] [thread 152258] Dumping entry 0
# Match key:
# * hdr.ipv4.dstAddr    : LPM       0a000101/32
# Action entry: MyIngress.forward - 0,
#
# [20:09:44.089] [bmv2] [T] [thread 152258] bm_table_add_entry
# [20:09:44.090] [bmv2] [D] [thread 152258] Entry 1 added to table 'MyIngress.ipv4_lpm'
# [20:09:44.090] [bmv2] [D] [thread 152258] Dumping entry 1
# Match key:
# * hdr.ipv4.dstAddr    : LPM       0a000102/32
# Action entry: MyIngress.forward - 1,
#
# h1-eth0: flags=4163<UP,BROADCAST,RUNNING,MULTICAST>  mtu 1500
#         inet 10.0.1.1  netmask 255.255.255.0  broadcast 10.0.1.255
#         inet6 fe80::200:ff:fe00:101  prefixlen 64  scopeid 0x20<link>
#         ether 00:00:00:00:01:01  txqueuelen 1000  (Ethernet)
#         RX packets 7  bytes 606 (606.0 B)
#         RX errors 0  dropped 0  overruns 0  frame 0
#         TX packets 7  bytes 646 (646.0 B)
#         TX errors 0  dropped 0 overruns 0  carrier 0  collisions 0
#
#
# Address                  HWtype  HWaddress           Flags Mask            Iface
# 10.0.1.2                 ether   00:00:00:00:01:02   CM                    h1-eth0
#
# h2-eth0: flags=4163<UP,BROADCAST,RUNNING,MULTICAST>  mtu 1500
#         inet 10.0.1.2  netmask 255.255.255.0  broadcast 10.0.1.255
#         inet6 fe80::200:ff:fe00:102  prefixlen 64  scopeid 0x20<link>
#         ether 00:00:00:00:01:02  txqueuelen 1000  (Ethernet)
#         RX packets 7  bytes 606 (606.0 B)
#         RX errors 0  dropped 0  overruns 0  frame 0
#         TX packets 7  bytes 646 (646.0 B)
#         TX errors 0  dropped 0 overruns 0  carrier 0  collisions 0
#
#
# [20:09:44.217] [bmv2] [D] [thread 152248] [18.0] [cxt 0] Processing packet received on port 1
# [20:09:44.217] [bmv2] [D] [thread 152248] [18.0] [cxt 0] Parser 'parser': start
# [20:09:44.217] [bmv2] [D] [thread 152248] [18.0] [cxt 0] Parser 'parser' entering state 'start'
# [20:09:44.217] [bmv2] [D] [thread 152248] [18.0] [cxt 0] Extracting header 'ethernet'
# [20:09:44.217] [bmv2] [D] [thread 152248] [18.0] [cxt 0] Parser state 'start': key is 86dd
# [20:09:44.217] [bmv2] [T] [thread 152248] [18.0] [cxt 0] Bytes parsed: 14
# [20:09:44.217] [bmv2] [D] [thread 152248] [18.0] [cxt 0] Parser 'parser': end
# [20:09:44.217] [bmv2] [D] [thread 152248] [18.0] [cxt 0] Pipeline 'ingress': start
# [20:09:44.217] [bmv2] [T] [thread 152248] [18.0] [cxt 0] forward.p4(106) Condition "hdr.ipv4.isValid()" (node_2) is false
# [20:09:44.217] [bmv2] [T] [thread 152248] [18.0] [cxt 0] forward.p4(108) Condition "hdr.ethernet.isValid()" (node_4) is true
# [20:09:44.217] [bmv2] [T] [thread 152248] [18.0] [cxt 0] Applying table 'MyIngress.ethernet_exact'
# [20:09:44.217] [bmv2] [D] [thread 152248] [18.0] [cxt 0] Looking up key:
# * hdr.ethernet.dstAddr: 333300000002
#
# [20:09:44.217] [bmv2] [D] [thread 152248] [18.0] [cxt 0] Table 'MyIngress.ethernet_exact': miss
# [20:09:44.217] [bmv2] [D] [thread 152248] [18.0] [cxt 0] Action entry is MyIngress.broadcast -
# [20:09:44.217] [bmv2] [T] [thread 152248] [18.0] [cxt 0] Action MyIngress.broadcast
# [20:09:44.217] [bmv2] [T] [thread 152248] [18.0] [cxt 0] forward.p4(74) Primitive standard_meta.mcast_grp = 1
# [20:09:44.217] [bmv2] [D] [thread 152248] [18.0] [cxt 0] Pipeline 'ingress': end
# [20:09:44.217] [bmv2] [D] [thread 152248] [18.0] [cxt 0] Multicast requested for packet
# [20:09:44.217] [bmv2] [D] [thread 152248] number of packets replicated : 2 for MGID: 1
# [20:09:44.217] [bmv2] [D] [thread 152248] [18.0] [cxt 0] Replicating packet on port 0
# [20:09:44.217] [bmv2] [D] [thread 152248] [18.0] [cxt 0] Replicating packet on port 1
# [20:09:44.217] [bmv2] [D] [thread 152249] [18.1] [cxt 0] Pipeline 'egress': start
# [20:09:44.217] [bmv2] [D] [thread 152249] [18.1] [cxt 0] Pipeline 'egress': end
# [20:09:44.218] [bmv2] [D] [thread 152249] [18.1] [cxt 0] Deparser 'deparser': start
# [20:09:44.218] [bmv2] [T] [thread 152249] [18.1] [cxt 0] Skipping checksum 'cksum' update because condition not met
# [20:09:44.218] [bmv2] [D] [thread 152249] [18.1] [cxt 0] Deparsing header 'ethernet'
# [20:09:44.218] [bmv2] [D] [thread 152249] [18.1] [cxt 0] Deparser 'deparser': end
# [20:09:44.218] [bmv2] [D] [thread 152253] [18.1] [cxt 0] Transmitting packet of size 70 out of port 0
# [20:09:44.218] [bmv2] [D] [thread 152250] [18.2] [cxt 0] Pipeline 'egress': start
# [20:09:44.218] [bmv2] [D] [thread 152250] [18.2] [cxt 0] Pipeline 'egress': end
# [20:09:44.218] [bmv2] [D] [thread 152250] [18.2] [cxt 0] Deparser 'deparser': start
# [20:09:44.218] [bmv2] [T] [thread 152250] [18.2] [cxt 0] Skipping checksum 'cksum' update because condition not met
# [20:09:44.218] [bmv2] [D] [thread 152250] [18.2] [cxt 0] Deparsing header 'ethernet'
# [20:09:44.218] [bmv2] [D] [thread 152250] [18.2] [cxt 0] Deparser 'deparser': end
# [20:09:44.218] [bmv2] [D] [thread 152253] [18.2] [cxt 0] Transmitting packet of size 70 out of port 1
# [20:09:44.473] [bmv2] [D] [thread 152248] [19.0] [cxt 0] Processing packet received on port 0
# [20:09:44.473] [bmv2] [D] [thread 152248] [19.0] [cxt 0] Parser 'parser': start
# [20:09:44.473] [bmv2] [D] [thread 152248] [19.0] [cxt 0] Parser 'parser' entering state 'start'
# [20:09:44.473] [bmv2] [D] [thread 152248] [19.0] [cxt 0] Extracting header 'ethernet'
# [20:09:44.473] [bmv2] [D] [thread 152248] [19.0] [cxt 0] Parser state 'start': key is 86dd
# [20:09:44.473] [bmv2] [T] [thread 152248] [19.0] [cxt 0] Bytes parsed: 14
# [20:09:44.473] [bmv2] [D] [thread 152248] [19.0] [cxt 0] Parser 'parser': end
# [20:09:44.473] [bmv2] [D] [thread 152248] [19.0] [cxt 0] Pipeline 'ingress': start
# [20:09:44.473] [bmv2] [T] [thread 152248] [19.0] [cxt 0] forward.p4(106) Condition "hdr.ipv4.isValid()" (node_2) is false
# [20:09:44.473] [bmv2] [T] [thread 152248] [19.0] [cxt 0] forward.p4(108) Condition "hdr.ethernet.isValid()" (node_4) is true
# [20:09:44.473] [bmv2] [T] [thread 152248] [19.0] [cxt 0] Applying table 'MyIngress.ethernet_exact'
# [20:09:44.473] [bmv2] [D] [thread 152248] [19.0] [cxt 0] Looking up key:
# * hdr.ethernet.dstAddr: 333300000002
#
# [20:09:44.473] [bmv2] [D] [thread 152248] [19.0] [cxt 0] Table 'MyIngress.ethernet_exact': miss
# [20:09:44.473] [bmv2] [D] [thread 152248] [19.0] [cxt 0] Action entry is MyIngress.broadcast -
# [20:09:44.473] [bmv2] [T] [thread 152248] [19.0] [cxt 0] Action MyIngress.broadcast
# [20:09:44.473] [bmv2] [T] [thread 152248] [19.0] [cxt 0] forward.p4(74) Primitive standard_meta.mcast_grp = 1
# [20:09:44.473] [bmv2] [D] [thread 152248] [19.0] [cxt 0] Pipeline 'ingress': end
# [20:09:44.473] [bmv2] [D] [thread 152248] [19.0] [cxt 0] Multicast requested for packet
# [20:09:44.473] [bmv2] [D] [thread 152248] number of packets replicated : 2 for MGID: 1
# [20:09:44.473] [bmv2] [D] [thread 152248] [19.0] [cxt 0] Replicating packet on port 0
# [20:09:44.473] [bmv2] [D] [thread 152248] [19.0] [cxt 0] Replicating packet on port 1
# [20:09:44.473] [bmv2] [D] [thread 152249] [19.1] [cxt 0] Pipeline 'egress': start
# [20:09:44.473] [bmv2] [D] [thread 152249] [19.1] [cxt 0] Pipeline 'egress': end
# [20:09:44.473] [bmv2] [D] [thread 152249] [19.1] [cxt 0] Deparser 'deparser': start
# [20:09:44.473] [bmv2] [T] [thread 152249] [19.1] [cxt 0] Skipping checksum 'cksum' update because condition not met
# [20:09:44.473] [bmv2] [D] [thread 152249] [19.1] [cxt 0] Deparsing header 'ethernet'
# [20:09:44.473] [bmv2] [D] [thread 152249] [19.1] [cxt 0] Deparser 'deparser': end
# [20:09:44.474] [bmv2] [D] [thread 152253] [19.1] [cxt 0] Transmitting packet of size 70 out of port 0
# [20:09:44.474] [bmv2] [D] [thread 152248] [20.0] [cxt 0] Processing packet received on port 1
# [20:09:44.474] [bmv2] [D] [thread 152248] [20.0] [cxt 0] Parser 'parser': start
# [20:09:44.474] [bmv2] [D] [thread 152248] [20.0] [cxt 0] Parser 'parser' entering state 'start'
# [20:09:44.474] [bmv2] [D] [thread 152248] [20.0] [cxt 0] Extracting header 'ethernet'
# [20:09:44.474] [bmv2] [D] [thread 152248] [20.0] [cxt 0] Parser state 'start': key is 86dd
# [20:09:44.474] [bmv2] [D] [thread 152250] [19.2] [cxt 0] Pipeline 'egress': start
# [20:09:44.474] [bmv2] [T] [thread 152248] [20.0] [cxt 0] Bytes parsed: 14
# [20:09:44.474] [bmv2] [D] [thread 152250] [19.2] [cxt 0] Pipeline 'egress': end
# [20:09:44.474] [bmv2] [D] [thread 152248] [20.0] [cxt 0] Parser 'parser': end
# [20:09:44.474] [bmv2] [D] [thread 152250] [19.2] [cxt 0] Deparser 'deparser': start
# [20:09:44.474] [bmv2] [D] [thread 152248] [20.0] [cxt 0] Pipeline 'ingress': start
# [20:09:44.474] [bmv2] [T] [thread 152250] [19.2] [cxt 0] Skipping checksum 'cksum' update because condition not met
# [20:09:44.474] [bmv2] [T] [thread 152248] [20.0] [cxt 0] forward.p4(106) Condition "hdr.ipv4.isValid()" (node_2) is false
# [20:09:44.474] [bmv2] [D] [thread 152250] [19.2] [cxt 0] Deparsing header 'ethernet'
# [20:09:44.474] [bmv2] [T] [thread 152248] [20.0] [cxt 0] forward.p4(108) Condition "hdr.ethernet.isValid()" (node_4) is true
# [20:09:44.474] [bmv2] [D] [thread 152250] [19.2] [cxt 0] Deparser 'deparser': end
# [20:09:44.474] [bmv2] [T] [thread 152248] [20.0] [cxt 0] Applying table 'MyIngress.ethernet_exact'
# [20:09:44.474] [bmv2] [D] [thread 152248] [20.0] [cxt 0] Looking up key:
# * hdr.ethernet.dstAddr: 333300000002
#
# [20:09:44.474] [bmv2] [D] [thread 152253] [19.2] [cxt 0] Transmitting packet of size 70 out of port 1
# [20:09:44.474] [bmv2] [D] [thread 152248] [20.0] [cxt 0] Table 'MyIngress.ethernet_exact': miss
# [20:09:44.474] [bmv2] [D] [thread 152248] [20.0] [cxt 0] Action entry is MyIngress.broadcast -
# [20:09:44.474] [bmv2] [T] [thread 152248] [20.0] [cxt 0] Action MyIngress.broadcast
# [20:09:44.474] [bmv2] [T] [thread 152248] [20.0] [cxt 0] forward.p4(74) Primitive standard_meta.mcast_grp = 1
# [20:09:44.474] [bmv2] [D] [thread 152248] [20.0] [cxt 0] Pipeline 'ingress': end
# [20:09:44.474] [bmv2] [D] [thread 152248] [20.0] [cxt 0] Multicast requested for packet
# [20:09:44.474] [bmv2] [D] [thread 152248] number of packets replicated : 2 for MGID: 1
# [20:09:44.474] [bmv2] [D] [thread 152248] [20.0] [cxt 0] Replicating packet on port 0
# [20:09:44.474] [bmv2] [D] [thread 152248] [20.0] [cxt 0] Replicating packet on port 1
# [20:09:44.474] [bmv2] [D] [thread 152250] [20.2] [cxt 0] Pipeline 'egress': start
# [20:09:44.474] [bmv2] [D] [thread 152250] [20.2] [cxt 0] Pipeline 'egress': end
# [20:09:44.474] [bmv2] [D] [thread 152250] [20.2] [cxt 0] Deparser 'deparser': start
# [20:09:44.474] [bmv2] [D] [thread 152249] [20.1] [cxt 0] Pipeline 'egress': start
# [20:09:44.474] [bmv2] [T] [thread 152250] [20.2] [cxt 0] Skipping checksum 'cksum' update because condition not met
# [20:09:44.474] [bmv2] [D] [thread 152249] [20.1] [cxt 0] Pipeline 'egress': end
# [20:09:44.474] [bmv2] [D] [thread 152250] [20.2] [cxt 0] Deparsing header 'ethernet'
# [20:09:44.474] [bmv2] [D] [thread 152249] [20.1] [cxt 0] Deparser 'deparser': start
# [20:09:44.474] [bmv2] [D] [thread 152250] [20.2] [cxt 0] Deparser 'deparser': end
# [20:09:44.474] [bmv2] [T] [thread 152249] [20.1] [cxt 0] Skipping checksum 'cksum' update because condition not met
# [20:09:44.474] [bmv2] [D] [thread 152249] [20.1] [cxt 0] Deparsing header 'ethernet'
# [20:09:44.474] [bmv2] [D] [thread 152253] [20.2] [cxt 0] Transmitting packet of size 70 out of port 1
# [20:09:44.474] [bmv2] [D] [thread 152249] [20.1] [cxt 0] Deparser 'deparser': end
# [20:09:44.474] [bmv2] [D] [thread 152253] [20.1] [cxt 0] Transmitting packet of size 70 out of port 0
# [20:09:44.729] [bmv2] [D] [thread 152248] [21.0] [cxt 0] Processing packet received on port 0
# [20:09:44.729] [bmv2] [D] [thread 152248] [21.0] [cxt 0] Parser 'parser': start
# [20:09:44.729] [bmv2] [D] [thread 152248] [21.0] [cxt 0] Parser 'parser' entering state 'start'
# [20:09:44.729] [bmv2] [D] [thread 152248] [21.0] [cxt 0] Extracting header 'ethernet'
# [20:09:44.729] [bmv2] [D] [thread 152248] [21.0] [cxt 0] Parser state 'start': key is 86dd
# [20:09:44.729] [bmv2] [T] [thread 152248] [21.0] [cxt 0] Bytes parsed: 14
# [20:09:44.729] [bmv2] [D] [thread 152248] [21.0] [cxt 0] Parser 'parser': end
# [20:09:44.729] [bmv2] [D] [thread 152248] [21.0] [cxt 0] Pipeline 'ingress': start
# [20:09:44.729] [bmv2] [T] [thread 152248] [21.0] [cxt 0] forward.p4(106) Condition "hdr.ipv4.isValid()" (node_2) is false
# [20:09:44.729] [bmv2] [T] [thread 152248] [21.0] [cxt 0] forward.p4(108) Condition "hdr.ethernet.isValid()" (node_4) is true
# [20:09:44.729] [bmv2] [T] [thread 152248] [21.0] [cxt 0] Applying table 'MyIngress.ethernet_exact'
# [20:09:44.729] [bmv2] [D] [thread 152248] [21.0] [cxt 0] Looking up key:
# * hdr.ethernet.dstAddr: 333300000002
#
# [20:09:44.729] [bmv2] [D] [thread 152248] [21.0] [cxt 0] Table 'MyIngress.ethernet_exact': miss
# [20:09:44.729] [bmv2] [D] [thread 152248] [21.0] [cxt 0] Action entry is MyIngress.broadcast -
# [20:09:44.729] [bmv2] [T] [thread 152248] [21.0] [cxt 0] Action MyIngress.broadcast
# [20:09:44.729] [bmv2] [T] [thread 152248] [21.0] [cxt 0] forward.p4(74) Primitive standard_meta.mcast_grp = 1
# [20:09:44.729] [bmv2] [D] [thread 152248] [21.0] [cxt 0] Pipeline 'ingress': end
# [20:09:44.729] [bmv2] [D] [thread 152248] [21.0] [cxt 0] Multicast requested for packet
# [20:09:44.729] [bmv2] [D] [thread 152248] number of packets replicated : 2 for MGID: 1
# [20:09:44.729] [bmv2] [D] [thread 152248] [21.0] [cxt 0] Replicating packet on port 0
# [20:09:44.729] [bmv2] [D] [thread 152248] [21.0] [cxt 0] Replicating packet on port 1
# [20:09:44.729] [bmv2] [D] [thread 152249] [21.1] [cxt 0] Pipeline 'egress': start
# [20:09:44.729] [bmv2] [D] [thread 152250] [21.2] [cxt 0] Pipeline 'egress': start
# [20:09:44.729] [bmv2] [D] [thread 152249] [21.1] [cxt 0] Pipeline 'egress': end
# [20:09:44.729] [bmv2] [D] [thread 152250] [21.2] [cxt 0] Pipeline 'egress': end
# [20:09:44.729] [bmv2] [D] [thread 152249] [21.1] [cxt 0] Deparser 'deparser': start
# [20:09:44.729] [bmv2] [D] [thread 152250] [21.2] [cxt 0] Deparser 'deparser': start
# [20:09:44.729] [bmv2] [T] [thread 152249] [21.1] [cxt 0] Skipping checksum 'cksum' update because condition not met
# [20:09:44.729] [bmv2] [T] [thread 152250] [21.2] [cxt 0] Skipping checksum 'cksum' update because condition not met
# [20:09:44.729] [bmv2] [D] [thread 152249] [21.1] [cxt 0] Deparsing header 'ethernet'
# ...
# [20:09:54.190] [bmv2] [D] [thread 152253] [48.0] [cxt 0] Transmitting packet of size 98 out of port 0
# [20:09:54.190] [bmv2] [D] [thread 152248] [49.0] [cxt 0] Processing packet received on port 0
# [20:09:54.190] [bmv2] [D] [thread 152248] [49.0] [cxt 0] Parser 'parser': start
# [20:09:54.190] [bmv2] [D] [thread 152248] [49.0] [cxt 0] Parser 'parser' entering state 'start'
# [20:09:54.190] [bmv2] [D] [thread 152248] [49.0] [cxt 0] Extracting header 'ethernet'
# [20:09:54.190] [bmv2] [D] [thread 152248] [49.0] [cxt 0] Parser state 'start': key is 0800
# [20:09:54.190] [bmv2] [T] [thread 152248] [49.0] [cxt 0] Bytes parsed: 14
# [20:09:54.190] [bmv2] [D] [thread 152248] [49.0] [cxt 0] Parser 'parser' entering state 'parse_ipv4'
# [20:09:54.190] [bmv2] [D] [thread 152248] [49.0] [cxt 0] Extracting header 'ipv4'
# [20:09:54.191] [bmv2] [D] [thread 152248] [49.0] [cxt 0] Parser state 'parse_ipv4' has no switch, going to default next state
# [20:09:54.191] [bmv2] [T] [thread 152248] [49.0] [cxt 0] Bytes parsed: 34
# [20:09:54.191] [bmv2] [D] [thread 152248] [49.0] [cxt 0] Parser 'parser': end
# [20:09:54.191] [bmv2] [D] [thread 152248] [49.0] [cxt 0] Pipeline 'ingress': start
# [20:09:54.191] [bmv2] [T] [thread 152248] [49.0] [cxt 0] forward.p4(106) Condition "hdr.ipv4.isValid()" (node_2) is true
# [20:09:54.191] [bmv2] [T] [thread 152248] [49.0] [cxt 0] Applying table 'MyIngress.ipv4_lpm'
# [20:09:54.191] [bmv2] [D] [thread 152248] [49.0] [cxt 0] Looking up key:
# * hdr.ipv4.dstAddr    : 0a000102
#
# [20:09:54.191] [bmv2] [D] [thread 152248] [49.0] [cxt 0] Table 'MyIngress.ipv4_lpm': hit with handle 1
# [20:09:54.191] [bmv2] [D] [thread 152248] [49.0] [cxt 0] Dumping entry 1
# Match key:
# * hdr.ipv4.dstAddr    : LPM       0a000102/32
# Action entry: MyIngress.forward - 1,
#
# [20:09:54.191] [bmv2] [D] [thread 152248] [49.0] [cxt 0] Action entry is MyIngress.forward - 1,
# [20:09:54.191] [bmv2] [T] [thread 152248] [49.0] [cxt 0] Action MyIngress.forward
# [20:09:54.191] [bmv2] [T] [thread 152248] [49.0] [cxt 0] forward.p4(71) Primitive standard_meta.egress_spec = port
# [20:09:54.191] [bmv2] [D] [thread 152248] [49.0] [cxt 0] Pipeline 'ingress': end
# [20:09:54.191] [bmv2] [D] [thread 152248] [49.0] [cxt 0] Egress port is 1
# [20:09:54.191] [bmv2] [D] [thread 152250] [49.0] [cxt 0] Pipeline 'egress': start
# [20:09:54.191] [bmv2] [D] [thread 152250] [49.0] [cxt 0] Pipeline 'egress': end
# [20:09:54.191] [bmv2] [D] [thread 152250] [49.0] [cxt 0] Deparser 'deparser': start
# [20:09:54.191] [bmv2] [D] [thread 152250] [49.0] [cxt 0] Updating checksum 'cksum'
# [20:09:54.191] [bmv2] [D] [thread 152250] [49.0] [cxt 0] Deparsing header 'ethernet'
# [20:09:54.191] [bmv2] [D] [thread 152250] [49.0] [cxt 0] Deparsing header 'ipv4'
# [20:09:54.191] [bmv2] [D] [thread 152250] [49.0] [cxt 0] Deparser 'deparser': end
# [20:09:54.191] [bmv2] [D] [thread 152253] [49.0] [cxt 0] Transmitting packet of size 98 out of port 1
# 0.0
# [20:10:08.793] [bmv2] [D] [thread 152248] [50.0] [cxt 0] Processing packet received on port 0
# [20:10:08.793] [bmv2] [D] [thread 152248] [50.0] [cxt 0] Parser 'parser': start
# [20:10:08.793] [bmv2] [D] [thread 152248] [50.0] [cxt 0] Parser 'parser' entering state 'start'
# [20:10:08.793] [bmv2] [D] [thread 152248] [50.0] [cxt 0] Extracting header 'ethernet'
# [20:10:08.793] [bmv2] [D] [thread 152248] [50.0] [cxt 0] Parser state 'start': key is 86dd
# [20:10:08.793] [bmv2] [T] [thread 152248] [50.0] [cxt 0] Bytes parsed: 14
# [20:10:08.793] [bmv2] [D] [thread 152248] [50.0] [cxt 0] Parser 'parser': end
# [20:10:08.793] [bmv2] [D] [thread 152248] [50.0] [cxt 0] Pipeline 'ingress': start
# [20:10:08.793] [bmv2] [T] [thread 152248] [50.0] [cxt 0] forward.p4(106) Condition "hdr.ipv4.isValid()" (node_2) is false
# [20:10:08.793] [bmv2] [T] [thread 152248] [50.0] [cxt 0] forward.p4(108) Condition "hdr.ethernet.isValid()" (node_4) is true
# [20:10:08.793] [bmv2] [T] [thread 152248] [50.0] [cxt 0] Applying table 'MyIngress.ethernet_exact'
# [20:10:08.793] [bmv2] [D] [thread 152248] [50.0] [cxt 0] Looking up key:
# * hdr.ethernet.dstAddr: 333300000002
#
# [20:10:08.793] [bmv2] [D] [thread 152248] [50.0] [cxt 0] Table 'MyIngress.ethernet_exact': miss
# [20:10:08.793] [bmv2] [D] [thread 152248] [50.0] [cxt 0] Action entry is MyIngress.broadcast -
# [20:10:08.793] [bmv2] [T] [thread 152248] [50.0] [cxt 0] Action MyIngress.broadcast
# [20:10:08.793] [bmv2] [T] [thread 152248] [50.0] [cxt 0] forward.p4(74) Primitive standard_meta.mcast_grp = 1
# [20:10:08.793] [bmv2] [D] [thread 152248] [50.0] [cxt 0] Pipeline 'ingress': end
# [20:10:08.793] [bmv2] [D] [thread 152248] [50.0] [cxt 0] Multicast requested for packet
# [20:10:08.793] [bmv2] [D] [thread 152248] number of packets replicated : 2 for MGID: 1
# [20:10:08.793] [bmv2] [D] [thread 152248] [50.0] [cxt 0] Replicating packet on port 0
# [20:10:08.793] [bmv2] [D] [thread 152248] [50.0] [cxt 0] Replicating packet on port 1
# [20:10:08.793] [bmv2] [D] [thread 152248] [51.0] [cxt 0] Processing packet received on port 0
# [20:10:08.793] [bmv2] [D] [thread 152248] [51.0] [cxt 0] Parser 'parser': start
# [20:10:08.793] [bmv2] [D] [thread 152248] [51.0] [cxt 0] Parser 'parser' entering state 'start'
# [20:10:08.793] [bmv2] [D] [thread 152249] [50.1] [cxt 0] Pipeline 'egress': start
# [20:10:08.793] [bmv2] [D] [thread 152250] [50.2] [cxt 0] Pipeline 'egress': start
# [20:10:08.793] [bmv2] [D] [thread 152248] [51.0] [cxt 0] Extracting header 'ethernet'
# [20:10:08.793] [bmv2] [D] [thread 152250] [50.2] [cxt 0] Pipeline 'egress': end
# [20:10:08.793] [bmv2] [D] [thread 152249] [50.1] [cxt 0] Pipeline 'egress': end
# [20:10:08.793] [bmv2] [D] [thread 152250] [50.2] [cxt 0] Deparser 'deparser': start
# [20:10:08.793] [bmv2] [D] [thread 152249] [50.1] [cxt 0] Deparser 'deparser': start
# [20:10:08.793] [bmv2] [D] [thread 152248] [51.0] [cxt 0] Parser state 'start': key is 86dd
# [20:10:08.793] [bmv2] [T] [thread 152250] [50.2] [cxt 0] Skipping checksum 'cksum' update because condition not met
# [20:10:08.793] [bmv2] [T] [thread 152249] [50.1] [cxt 0] Skipping checksum 'cksum' update because condition not met
# [20:10:08.793] [bmv2] [T] [thread 152248] [51.0] [cxt 0] Bytes parsed: 14
# [20:10:08.793] [bmv2] [D] [thread 152250] [50.2] [cxt 0] Deparsing header 'ethernet'
# [20:10:08.793] [bmv2] [D] [thread 152249] [50.1] [cxt 0] Deparsing header 'ethernet'
# [20:10:08.793] [bmv2] [D] [thread 152248] [51.0] [cxt 0] Parser 'parser': end
# [20:10:08.793] [bmv2] [D] [thread 152250] [50.2] [cxt 0] Deparser 'deparser': end
# [20:10:08.793] [bmv2] [D] [thread 152249] [50.1] [cxt 0] Deparser 'deparser': end
# [20:10:08.793] [bmv2] [D] [thread 152248] [51.0] [cxt 0] Pipeline 'ingress': start
# [20:10:08.793] [bmv2] [T] [thread 152248] [51.0] [cxt 0] forward.p4(106) Condition "hdr.ipv4.isValid()" (node_2) is false
# [20:10:08.794] [bmv2] [T] [thread 152248] [51.0] [cxt 0] forward.p4(108) Condition "hdr.ethernet.isValid()" (node_4) is true
# [20:10:08.794] [bmv2] [T] [thread 152248] [51.0] [cxt 0] Applying table 'MyIngress.ethernet_exact'
# [20:10:08.794] [bmv2] [D] [thread 152253] [50.2] [cxt 0] Transmitting packet of size 70 out of port 1
# [20:10:08.794] [bmv2] [D] [thread 152248] [51.0] [cxt 0] Looking up key:
# * hdr.ethernet.dstAddr: 333300000002
#
# [20:10:08.794] [bmv2] [D] [thread 152253] [50.1] [cxt 0] Transmitting packet of size 70 out of port 0
# [20:10:08.794] [bmv2] [D] [thread 152248] [51.0] [cxt 0] Table 'MyIngress.ethernet_exact': miss
# [20:10:08.794] [bmv2] [D] [thread 152248] [51.0] [cxt 0] Action entry is MyIngress.broadcast -
# [20:10:08.794] [bmv2] [T] [thread 152248] [51.0] [cxt 0] Action MyIngress.broadcast
# [20:10:08.794] [bmv2] [T] [thread 152248] [51.0] [cxt 0] forward.p4(74) Primitive standard_meta.mcast_grp = 1
# [20:10:08.794] [bmv2] [D] [thread 152248] [51.0] [cxt 0] Pipeline 'ingress': end
# [20:10:08.794] [bmv2] [D] [thread 152248] [51.0] [cxt 0] Multicast requested for packet
# [20:10:08.794] [bmv2] [D] [thread 152248] number of packets replicated : 2 for MGID: 1
# [20:10:08.794] [bmv2] [D] [thread 152248] [51.0] [cxt 0] Replicating packet on port 0
# [20:10:08.794] [bmv2] [D] [thread 152248] [51.0] [cxt 0] Replicating packet on port 1
# [20:10:08.794] [bmv2] [D] [thread 152249] [51.1] [cxt 0] Pipeline 'egress': start
# [20:10:08.794] [bmv2] [D] [thread 152250] [51.2] [cxt 0] Pipeline 'egress': start
# [20:10:08.794] [bmv2] [D] [thread 152249] [51.1] [cxt 0] Pipeline 'egress': end
# [20:10:08.794] [bmv2] [D] [thread 152250] [51.2] [cxt 0] Pipeline 'egress': end
# [20:10:08.794] [bmv2] [D] [thread 152249] [51.1] [cxt 0] Deparser 'deparser': start
# [20:10:08.794] [bmv2] [D] [thread 152250] [51.2] [cxt 0] Deparser 'deparser': start
# [20:10:08.794] [bmv2] [T] [thread 152249] [51.1] [cxt 0] Skipping checksum 'cksum' update because condition not met
# [20:10:08.794] [bmv2] [T] [thread 152250] [51.2] [cxt 0] Skipping checksum 'cksum' update because condition not met
# [20:10:08.794] [bmv2] [D] [thread 152249] [51.1] [cxt 0] Deparsing header 'ethernet'
# [20:10:08.794] [bmv2] [D] [thread 152250] [51.2] [cxt 0] Deparsing header 'ethernet'
# [20:10:08.794] [bmv2] [D] [thread 152249] [51.1] [cxt 0] Deparser 'deparser': end
# [20:10:08.794] [bmv2] [D] [thread 152250] [51.2] [cxt 0] Deparser 'deparser': end
# [20:10:08.794] [bmv2] [D] [thread 152253] [51.1] [cxt 0] Transmitting packet of size 70 out of port 0
# [20:10:08.794] [bmv2] [D] [thread 152253] [51.2] [cxt 0] Transmitting packet of size 70 out of port 1
# [20:10:09.817] [bmv2] [D] [thread 152248] [52.0] [cxt 0] Processing packet received on port 1
# [20:10:09.817] [bmv2] [D] [thread 152248] [52.0] [cxt 0] Parser 'parser': start
# [20:10:09.817] [bmv2] [D] [thread 152248] [52.0] [cxt 0] Parser 'parser' entering state 'start'
# [20:10:09.817] [bmv2] [D] [thread 152248] [52.0] [cxt 0] Extracting header 'ethernet'
# [20:10:09.817] [bmv2] [D] [thread 152248] [52.0] [cxt 0] Parser state 'start': key is 86dd
# [20:10:09.817] [bmv2] [T] [thread 152248] [52.0] [cxt 0] Bytes parsed: 14
# [20:10:09.817] [bmv2] [D] [thread 152248] [52.0] [cxt 0] Parser 'parser': end
# [20:10:09.817] [bmv2] [D] [thread 152248] [52.0] [cxt 0] Pipeline 'ingress': start
# [20:10:09.817] [bmv2] [T] [thread 152248] [52.0] [cxt 0] forward.p4(106) Condition "hdr.ipv4.isValid()" (node_2) is false
# [20:10:09.817] [bmv2] [T] [thread 152248] [52.0] [cxt 0] forward.p4(108) Condition "hdr.ethernet.isValid()" (node_4) is true
# [20:10:09.817] [bmv2] [T] [thread 152248] [52.0] [cxt 0] Applying table 'MyIngress.ethernet_exact'
# [20:10:09.817] [bmv2] [D] [thread 152248] [52.0] [cxt 0] Looking up key:
# * hdr.ethernet.dstAddr: 333300000002
#
# [20:10:09.817] [bmv2] [D] [thread 152248] [52.0] [cxt 0] Table 'MyIngress.ethernet_exact': miss
# [20:10:09.817] [bmv2] [D] [thread 152248] [52.0] [cxt 0] Action entry is MyIngress.broadcast -
# [20:10:09.817] [bmv2] [T] [thread 152248] [52.0] [cxt 0] Action MyIngress.broadcast
# [20:10:09.817] [bmv2] [T] [thread 152248] [52.0] [cxt 0] forward.p4(74) Primitive standard_meta.mcast_grp = 1
# [20:10:09.817] [bmv2] [D] [thread 152248] [52.0] [cxt 0] Pipeline 'ingress': end
# [20:10:09.817] [bmv2] [D] [thread 152248] [52.0] [cxt 0] Multicast requested for packet
# [20:10:09.817] [bmv2] [D] [thread 152248] number of packets replicated : 2 for MGID: 1
# [20:10:09.817] [bmv2] [D] [thread 152248] [52.0] [cxt 0] Replicating packet on port 0
# [20:10:09.817] [bmv2] [D] [thread 152248] [52.0] [cxt 0] Replicating packet on port 1
# [20:10:09.817] [bmv2] [D] [thread 152248] [53.0] [cxt 0] Processing packet received on port 1
# [20:10:09.817] [bmv2] [D] [thread 152248] [53.0] [cxt 0] Parser 'parser': start
# [20:10:09.817] [bmv2] [D] [thread 152248] [53.0] [cxt 0] Parser 'parser' entering state 'start'
# [20:10:09.817] [bmv2] [D] [thread 152249] [52.1] [cxt 0] Pipeline 'egress': start
# [20:10:09.817] [bmv2] [D] [thread 152248] [53.0] [cxt 0] Extracting header 'ethernet'
# [20:10:09.817] [bmv2] [D] [thread 152250] [52.2] [cxt 0] Pipeline 'egress': start
# [20:10:09.817] [bmv2] [D] [thread 152249] [52.1] [cxt 0] Pipeline 'egress': end
# [20:10:09.817] [bmv2] [D] [thread 152248] [53.0] [cxt 0] Parser state 'start': key is 86dd
# [20:10:09.817] [bmv2] [D] [thread 152250] [52.2] [cxt 0] Pipeline 'egress': end
# [20:10:09.817] [bmv2] [D] [thread 152249] [52.1] [cxt 0] Deparser 'deparser': start
# [20:10:09.817] [bmv2] [T] [thread 152248] [53.0] [cxt 0] Bytes parsed: 14
# [20:10:09.817] [bmv2] [D] [thread 152250] [52.2] [cxt 0] Deparser 'deparser': start
# [20:10:09.817] [bmv2] [D] [thread 152248] [53.0] [cxt 0] Parser 'parser': end
# [20:10:09.817] [bmv2] [T] [thread 152249] [52.1] [cxt 0] Skipping checksum 'cksum' update because condition not met
# [20:10:09.817] [bmv2] [T] [thread 152250] [52.2] [cxt 0] Skipping checksum 'cksum' update because condition not met
# [20:10:09.817] [bmv2] [D] [thread 152249] [52.1] [cxt 0] Deparsing header 'ethernet'
# [20:10:09.817] [bmv2] [D] [thread 152248] [53.0] [cxt 0] Pipeline 'ingress': start
# [20:10:09.817] [bmv2] [D] [thread 152249] [52.1] [cxt 0] Deparser 'deparser': end
# [20:10:09.817] [bmv2] [D] [thread 152250] [52.2] [cxt 0] Deparsing header 'ethernet'
# [20:10:09.817] [bmv2] [D] [thread 152250] [52.2] [cxt 0] Deparser 'deparser': end
# [20:10:09.817] [bmv2] [T] [thread 152248] [53.0] [cxt 0] forward.p4(106) Condition "hdr.ipv4.isValid()" (node_2) is false
# [20:10:09.818] [bmv2] [T] [thread 152248] [53.0] [cxt 0] forward.p4(108) Condition "hdr.ethernet.isValid()" (node_4) is true
# [20:10:09.818] [bmv2] [T] [thread 152248] [53.0] [cxt 0] Applying table 'MyIngress.ethernet_exact'
# [20:10:09.818] [bmv2] [D] [thread 152253] [52.1] [cxt 0] Transmitting packet of size 70 out of port 0
# [20:10:09.818] [bmv2] [D] [thread 152248] [53.0] [cxt 0] Looking up key:
# * hdr.ethernet.dstAddr: 333300000002
#
# [20:10:09.818] [bmv2] [D] [thread 152248] [53.0] [cxt 0] Table 'MyIngress.ethernet_exact': miss
# [20:10:09.818] [bmv2] [D] [thread 152248] [53.0] [cxt 0] Action entry is MyIngress.broadcast -
# [20:10:09.818] [bmv2] [D] [thread 152253] [52.2] [cxt 0] Transmitting packet of size 70 out of port 1
# [20:10:09.818] [bmv2] [T] [thread 152248] [53.0] [cxt 0] Action MyIngress.broadcast
# [20:10:09.818] [bmv2] [T] [thread 152248] [53.0] [cxt 0] forward.p4(74) Primitive standard_meta.mcast_grp = 1
# [20:10:09.818] [bmv2] [D] [thread 152248] [53.0] [cxt 0] Pipeline 'ingress': end
# [20:10:09.818] [bmv2] [D] [thread 152248] [53.0] [cxt 0] Multicast requested for packet
# [20:10:09.818] [bmv2] [D] [thread 152248] number of packets replicated : 2 for MGID: 1
# [20:10:09.818] [bmv2] [D] [thread 152248] [53.0] [cxt 0] Replicating packet on port 0
# [20:10:09.818] [bmv2] [D] [thread 152248] [53.0] [cxt 0] Replicating packet on port 1
# [20:10:09.818] [bmv2] [D] [thread 152249] [53.1] [cxt 0] Pipeline 'egress': start
# [20:10:09.818] [bmv2] [D] [thread 152249] [53.1] [cxt 0] Pipeline 'egress': end
# [20:10:09.818] [bmv2] [D] [thread 152249] [53.1] [cxt 0] Deparser 'deparser': start
# [20:10:09.818] [bmv2] [D] [thread 152250] [53.2] [cxt 0] Pipeline 'egress': start
# [20:10:09.818] [bmv2] [T] [thread 152249] [53.1] [cxt 0] Skipping checksum 'cksum' update because condition not met
# [20:10:09.818] [bmv2] [D] [thread 152250] [53.2] [cxt 0] Pipeline 'egress': end
# [20:10:09.818] [bmv2] [D] [thread 152249] [53.1] [cxt 0] Deparsing header 'ethernet'
# [20:10:09.818] [bmv2] [D] [thread 152250] [53.2] [cxt 0] Deparser 'deparser': start
# [20:10:09.818] [bmv2] [D] [thread 152249] [53.1] [cxt 0] Deparser 'deparser': end
# [20:10:09.818] [bmv2] [T] [thread 152250] [53.2] [cxt 0] Skipping checksum 'cksum' update because condition not met
# [20:10:09.818] [bmv2] [D] [thread 152250] [53.2] [cxt 0] Deparsing header 'ethernet'
# [20:10:09.818] [bmv2] [D] [thread 152253] [53.1] [cxt 0] Transmitting packet of size 70 out of port 0
# [20:10:09.818] [bmv2] [D] [thread 152250] [53.2] [cxt 0] Deparser 'deparser': end
# [20:10:09.818] [bmv2] [D] [thread 152253] [53.2] [cxt 0] Transmitting packet of size 70 out of port 1
# mininet>  exit
# *** Stopping 0 controllers
#
# *** Stopping 2 links
# ..
# *** Stopping 1 switches
# s1 *** Stopping P4 switch s1
# open: No such file or directory
# open: No such file or directory
#
# *** Stopping 2 hosts
# h1 h2
# *** Done
